# %% [markdown]
# <a href="https://colab.research.google.com/github/rajucherry03/Deep_Learning/blob/main/Exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 #Experiment-1
#Basic image processing operations: Histogram equalization, thresholding,
#edge detection, data augmentation, morphological operations
import cv2
import numpy as np
from matplotlib import pyplot as plt
import numpy as np

# %%
# Load an image
image_path = "/content/drive/MyDrive/Mahendra_Singh_Dhoni_receiving_Padma_Bhushan.jpg"

# %%
original_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# %%
# Display the original image
plt.figure(figsize=(8, 8))
plt.subplot(2, 3, 1)
plt.imshow(original_image, cmap='gray')
plt.title('Original Image')
# Out:
# Text(0.5, 1.0, 'Original Image')

# %%
# Histogram Equalization
equalized_image = cv2.equalizeHist(original_image)
plt.subplot(2, 3, 2)
plt.imshow(equalized_image, cmap='gray')
plt.title('Histogram Equalization')
# Out:
# Text(0.5, 1.0, 'Histogram Equalization')

# %%
# Thresholding
_, thresholded_image = cv2.threshold(original_image, 128, 255, cv2.THRESH_BINARY)
plt.subplot(2, 3, 3)
plt.imshow(thresholded_image, cmap='gray')
plt.title('Thresholding')
# Out:
# Text(0.5, 1.0, 'Thresholding')

# %%
# Edge Detection (using Canny)
edges = cv2.Canny(original_image, 100, 200)
plt.subplot(2, 3, 4)
plt.imshow(edges, cmap='gray')
plt.title('Edge Detection')
# Out:
# Text(0.5, 1.0, 'Edge Detection')

# %%
edges = cv2.Canny(original_image,100,150)
plt.subplot(2,3,4)
plt.imshow(edges,cmap='gray')
plt.title('Edge Detection')
# Out:
# Text(0.5, 1.0, 'Edge Detection')

# %%
# Data Augmentation (rotate image)
rows, cols = original_image.shape
rotation_matrix = cv2.getRotationMatrix2D((cols / 2, rows / 2), 45, 1)
rotated_image = cv2.warpAffine(original_image, rotation_matrix, (cols, rows))
plt.subplot(2, 3, 5)
plt.imshow(rotated_image, cmap='gray')
plt.title('Data Augmentation (Rotation)')
# Out:
# Text(0.5, 1.0, 'Data Augmentation (Rotation)')

# %%
# Morphological Operations (Dilation)
kernel = np.ones((5, 5), np.uint8)
dilated_image = cv2.dilate(original_image, kernel, iterations=1)
plt.subplot(2, 3, 6)
plt.imshow(dilated_image, cmap='gray')
plt.title('Morphological Operation (Dilation)')
# Out:
# Text(0.5, 1.0, 'Morphological Operation (Dilation)')

# %%
# Display the original image
plt.figure(figsize=(8, 8))
plt.subplot(2, 3, 1)
plt.imshow(original_image, cmap='gray')
plt.title('Original Image')
# Histogram Equalization
equalized_image = cv2.equalizeHist(original_image)
plt.subplot(2, 3, 2)
plt.imshow(equalized_image, cmap='gray')
plt.title('Histogram Equalization')
# Thresholding
_, thresholded_image = cv2.threshold(original_image, 128, 255, cv2.THRESH_BINARY)
plt.subplot(2, 3, 3)
plt.imshow(thresholded_image, cmap='gray')
plt.title('Thresholding')
# Edge Detection (using Canny)
edges = cv2.Canny(original_image, 100, 200)
plt.subplot(2, 3, 4)
plt.imshow(edges, cmap='gray')
plt.title('Edge Detection')
# Data Augmentation (rotate image)
rows, cols = original_image.shape
rotation_matrix = cv2.getRotationMatrix2D((cols / 2, rows / 2), 45, 1)
rotated_image = cv2.warpAffine(original_image, rotation_matrix, (cols, rows))
plt.subplot(2, 3, 5)
plt.imshow(rotated_image, cmap='gray')
plt.title('Data Augmentation (Rotation)')
# Morphological Operations (Dilation)
kernel = np.ones((5, 5), np.uint8)
dilated_image = cv2.dilate(original_image, kernel, iterations=1)
plt.subplot(2, 3, 6)
plt.imshow(dilated_image, cmap='gray')
plt.title('Morphological Operation (Dilation)')
# Show the plots
plt.tight_layout()
plt.show()
